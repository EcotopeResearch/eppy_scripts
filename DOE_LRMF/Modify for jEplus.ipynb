# %%
import numpy as np
import pandas as pd
import sys
import os

from eppy import hvacbuilder
from eppy import modeleditor
from eppy.modeleditor import IDF

# %%
## this function determines what idf version and connects the idd for eppy

def eppy_connection(idffile):
    fp = open(idffile)
    lines=fp.readlines()
    vers = ""
    vers = vers.join(lines[2:12])
    vers
    if vers.find('8.7') != -1:
        print('Using EnergyPlus version 8.7')
        iddfile = 'C:\\EnergyPlusV8-7-0\\Energy+.idd'
        IDF.setiddname(iddfile)
        idf = IDF(idffile)
        return idf
    elif vers.find('8.8') != -1:
        print('Using EnergyPlus version 8.8')
        iddfile = 'C:\\EnergyPlusV8-8-0\\Energy+.idd'
        IDF.setiddname(iddfile)
        idf = IDF(idffile)
        return idf
    elif vers.find('8.9') != -1:
        print('Using EnergyPlus version 8.9')
        iddfile = 'C:\\EnergyPlusV8-9-0\\Energy+.idd'
        IDF.setiddname(iddfile)
        idf = IDF(idffile)
        return idf
    elif vers.find('9.0') != -1:
        print('Using EnergyPlus version 9.0.1')
        iddfile = 'C:\\EnergyPlusV9-0-1\\Energy+.idd'
        IDF.setiddname(iddfile)
        idf = IDF(idffile)
        return idf
    else:
        print('IDF Type not found on line 3')

# %%
## CONNECT IDFS

#define paths
commonSlab_path = 'C:\\Users\\scott\\github\\DOE_LRMF\\SEED_Models\\common_hp_slab_IECC_2012_V8.7.idf'
commonBsmt_path = 'C:\\Users\\scott\\github\\DOE_LRMF\\SEED_Models\\common_hp_heatedbsmtIECC_2012_V8.7.idf'
gardenSlab_path = 'C:\\Users\\scott\\github\\DOE_LRMF\\SEED_Models\\garden_hp_slab_IECC_2012_V8.7.idf'
gardenBsmt_path = 'C:\\Users\\scott\\github\\DOE_LRMF\\SEED_Models\\garden_hp_heatedbsmtIECC_2012_V8.7.idf'

#make connections
commonSlab = eppy_connection(commonSlab_path)
commonBsmt = eppy_connection(commonBsmt_path)
gardenSlab = eppy_connection(gardenSlab_path)
gardenBsmt = eppy_connection(gardenBsmt_path)

# create groups
idfs = [commonSlab, commonBsmt, gardenSlab, gardenBsmt]
common = [commonSlab, commonBsmt]
garden = [gardenSlab, gardenBsmt]
bsmt = [commonBsmt, gardenBsmt]
slab = [commonSlab, gardenSlab]
# Out:
# Using EnergyPlus version 8.7
# Using EnergyPlus version 8.7
# Using EnergyPlus version 8.7
# Using EnergyPlus version 8.7

# %%
## IMPORT INPUT DATAFRAMES

path = 'C:\\Users\\scott\\github\\eppy_scripts\\DOE_LRMF\\inputs\\'
filename = 'idf_vars.csv'

inputs_table = pd.read_csv(path + filename)
inputs_table
# Out:
#                            Description jEplus - Variable  \
# 0                Exterior wall U-value         @@WALLU@@
# 1                      Ceiling U-value      @@CEILINGU@@
# 2                   Foundation U-value         @@FNDNU@@
# 3                    bsmt wall U-value        @@BSMTWU@@
# 4                      Windows U-value          @@WINU@@
# 5                         Windows SHGC          @@SHGC@@
# 6    Corridor heating efficiency (COP)      @@CORHTCOP@@
# 7   Corridor heating efficiency curves   @@CORHTCURVES@@
# 8   Corridor heating setpoint temp (F)       @@CORHTST@@
# 9    Corridor cooling efficiency (COP)      @@CORCLCOP@@
# 10  Corridor cooling efficiency curves   @@CORCLCURVES@@
# 11  Corridor cooling setpoint temp (F)       @@CORCLST@@
# 12       Bsmt heating efficiency (COP)     @@BSMTHTCOP@@
# 13      Bsmt Heating efficiency curves  @@BSMTHTCURVES@@
# 14      bsmt heating setpoint temp (F)      @@BSMTHTST@@
# 15       Bsmt cooling efficiency (COP)     @@BSMTCLCOP@@
# 16      Bsmt cooling efficiency curves  @@BSMTCLCURVES@@
# 17      bsmt cooling setpoint temp (F)      @@BSMTCLST@@
# 18               LPD - corridor (W/sf)        @@LPDCOR@@
# 19              Lighting Stairwell (W)        @@LTGSTR@@
# 20           exterior corridor LPD (W)     @@LTGEXTCOR@@
# 21         internal parking LPD (W/sf)     @@LTGINTPKG@@
# 22         external parking LPD (W/sf)     @@LTGEXTPKG@@
# 23    In-unit heating efficiency (COP)     @@UNITHTCOP@@
# 24   In-unit heating efficiency curves  @@UNITHTCURVES@@
# 25   in-unit heating setpoint temp (F)      @@UNITHTST@@
# 26    In-unit cooling efficiency (COP)     @@UNITCLCOP@@
# 27   In-unit cooling efficiency curves  @@UNITCLCURVES@@
# 28   In-unit cooling setpoint temp (F)      @@UNITCLST@@
# 29                  In-unit LPD (W/sf)       @@UNITLPD@@
# 30              In-unit DHW efficiency        @@DHWCOP@@
# 31          Distribution Load (W/unit)       @@DHWGAIN@@
#
#                            Object Type                   Name  \
# 0                             Material      wall_consol_layer
# 1                             Material      ceil_consol_layer
# 2                             Material     floor_consol_layer
# 3                             Material  bsmtwall_consol_layer
# 4   WindowMaterial:SimpleGlazingSystem                  Glass
# 5   WindowMaterial:SimpleGlazingSystem                  Glass
# 6          Coil:Heating:DX:SingleSpeed    listCorridorsDXheat
# 7          Coil:Heating:DX:SingleSpeed  listHVACtypeCurveHeat
# 8                     Schedule:Compact       heating_sch_corr
# 9          Coil:Cooling:DX:SingleSpeed    listCorridorsDXcool
# 10         Coil:Cooling:DX:SingleSpeed  listHVACtypeCurveCool
# 11                    Schedule:Compact       cooling_sch_corr
# 12         Coil:Heating:DX:SingleSpeed        listBsmtsDXheat
# 13         Coil:Heating:DX:SingleSpeed  listHVACtypeCurveHeat
# 14                    Schedule:Compact       heating_sch_bsmt
# 15         Coil:Cooling:DX:SingleSpeed        listBsmtsDXcool
# 16         Coil:Cooling:DX:SingleSpeed  listHVACtypeCurveCool
# 17                    Schedule:Compact       cooling_sch_bsmt
# 18                              Lights         listCorrLights
# 19                     Exterior:Lights              stairLtgs
# 20                     Exterior:Lights          CorrExtLights
# 21                     Exterior:Lights             intPrkLtgs
# 22                     Exterior:Lights             extPrkLtgs
# 23         Coil:Heating:DX:SingleSpeed         listUnitDXheat
# 24         Coil:Heating:DX:SingleSpeed  listHVACtypeCurveHeat
# 25                    Schedule:Compact       heating_sch_unit
# 26         Coil:Cooling:DX:SingleSpeed         listUnitDXcool
# 27         Coil:Cooling:DX:SingleSpeed  listHVACtypeCurveCool
# 28                    Schedule:Compact       cooling_sch_unit
# 29                              Lights         listUnitLights
# 30                   WaterHeater:Mixed       listWaterHeaters
# 31                   WaterHeater:Mixed       listWaterHeaters
#
#                         Value  Models
# 0                Conductivity     all
# 1                Conductivity     all
# 2                Conductivity     all
# 3                Conductivity    bsmt
# 4                     UFactor     all
# 5                     UFactor     all
# 6     Gross_Rated_Heating_COP  common
# 7                listDXcurves  common
# 8                     Field 4  common
# 9     Gross_Rated_Cooling_COP  common
# 10               listDXcurves  common
# 11                    Field 4  common
# 12    Gross_Rated_Heating_COP    bsmt
# 13               listDXcurves    bsmt
# 14                    Field 4    bsmt
# 15    Gross_Rated_Cooling_COP    bsmt
# 16               listDXcurves    bsmt
# 17                    Field 4    bsmt
# 18  Watts per Zone Floor Area  common
# 19               Design Level     all
# 20               Design Level  garden
# 21               Design Level     all
# 22               Design Level     all
# 23    Gross_Rated_Heating_COP     all
# 24               listDXcurves     all
# 25                    Field 4     all
# 26    Gross_Rated_Cooling_COP     all
# 27               listDXcurves     all
# 28                    Field 4     all
# 29  Watts per Zone Floor Area     all
# 30  Heater Thermal Efficiency     all
# 31              listDHWlosses     all
